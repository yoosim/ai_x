# %%
# pip install pymysql
import pymysql
conn = pymysql.connect(host='210.121.189.12',
												user='remoteuser', 
												password='mbcdkzkepal0902!', 
												database='devdb',
												charset='utf-8')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[4], line 3
#       1 # pip install pymysql
#       2 import pymysql
# ----> 3 conn = pymysql.connect(host='210.121.189.12',
#       4 												user='remoteuser',
#       5 												password='mbcdkzkepal0902!',
#       6 												database='devdb',
#       7 												charset='utf-8')
#
# ...

# %%
cousor = conn.cursor()
sql = "INSERT INTO PERSON VALUES (%spno, %spname, 'ceo', null, curdate(), 9000,10,40)"
pno = input("Enter Person No:")
pname = input("Enter Person Name:")
cursor.excute(sql,(pno, pname))
print("수행결과 :", cursor.rowcount)
# conn.commit()
cursor.close()
