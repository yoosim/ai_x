# %%
from IPython.display import display, HTML
display(HTML("""
<style>
div.container{width:100% !important;}
div.cell.code_cell.rendered{width:100%;}
div.input_prompt{padding:0px;}
div.CodeMirror {font-family:Consolas; font-size:22pt;}
div.text_cell_render.rendered_html{font-size:18pt;}
div.text_cell_render.rendered_html{font-size:15pt;}
div.output {font-size:18pt; font-weight:bold;}
div.input {font-family:Consolas; font-size:18pt;}
div.prompt {min-width:70px;}
div#toc-wrapper{padding-top:120px;}
div.text_cell_render ul li{font-size:18pt;padding:5px;}
table.dataframe{font-size:18px;}
</style>
"""))
# Out:
# <style>
# div.container{width:100% !important;}
# div.cell.code_cell.rendered{width:100%;}
# div.input_prompt{padding:0px;}
# div.CodeMirror {font-family:Consolas; font-size:22pt;}
# div.text_cell_render.rendered_html{font-size:18pt;}
# div.text_cell_render.rendered_html{font-size:15pt;}
# div.output {font-size:18pt; font-weight:bold;}
# div.input {font-family:Consolas; font-size:18pt;}
# div.prompt {min-width:70px;}
# div#toc-wrapper{padding-top:120px;}
# div.text_cell_render ul li{font-size:18pt;padding:5px;}
# table.dataframe{font-size:18px;}
# </style>

# %% [markdown]
# # 1. 환경(패키지 및 환경변수)
# - pip install langchain-ollama
# - pip install langchain-community

# %%
# %pip install -q langchain-community
# Out:
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# # 2.LLM 답변 생성
# - ollama.com 에서 모델 선택(ollama run llama3.2:1b)
# - powershell이나 cmd창에서 ollama pull llama3.2:1b (run-지금 실행, pull-가져오기)

# %%
from langchain_ollama import ChatOllama
# from langchain_community.chat_models import ChatOllama
llm = ChatOllama(model="llama3.2:1b")
ai_message = llm.invoke("2020년 월드 시리즈에서 누가 우승했나요?")
ai_message.content
# Out:
# '2020 년 월드 시리즈는 코미즈카 대학교와 유니버시티 오브 드림스 간의 월드 시리즈로, 우승은 코미즈카 대학교입니다.'

# %% [markdown]
# # 3. 코랩에서 ollama(exaone3.5:2.4b) 돌리기
# -http://bit.ly/3IKpnVH
